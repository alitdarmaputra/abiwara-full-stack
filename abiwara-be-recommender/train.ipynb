# %% [markdown]
# # Books Recommendation with SVD and Collaborative Filtering

# %% [markdown]
# ## Import library

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from surprise import Dataset, Reader, accuracy, SVD
import pickle, gzip, pickletools

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv("./input/ratings.csv")
df = pd.DataFrame({
    "user_id": df["UserID"],
    "book_id": df["BookID"],
    "rating": df["Rating"]
})
df
# Out:
#                                      user_id  book_id  rating
# 0       51e49f25-397d-43a1-a807-005933626d2e     1283       3
# 1       51e49f25-397d-43a1-a807-005933626d2e       11       3
# 2       51e49f25-397d-43a1-a807-005933626d2e      207       3
# 3       51e49f25-397d-43a1-a807-005933626d2e      312       3
# 4       51e49f25-397d-43a1-a807-005933626d2e      824       4
# ...                                      ...      ...     ...
# 124836  b06db5a6-f1ca-4f2a-ab7f-90109157e4be      861       4
# 124837  b06db5a6-f1ca-4f2a-ab7f-90109157e4be      449       3
# 124838  b06db5a6-f1ca-4f2a-ab7f-90109157e4be      664       3
# 124839  b06db5a6-f1ca-4f2a-ab7f-90109157e4be      208       3
# 124840  b06db5a6-f1ca-4f2a-ab7f-90109157e4be      113       3
#
# [124841 rows x 3 columns]

# %%
print(df["book_id"].unique().shape)
# Out:
# (886,)

# %% [markdown]
# ### Choose books with a certain number of ratings

# %%
df1 = df.drop("rating", axis=1)
df1 = pd.DataFrame(df1.groupby(["book_id"]).count())
df1.sort_values(by='user_id')
# Out:
#          user_id
# book_id
# 32           102
# 33           102
# 36           102
# 915          102
# 922          102
# ...          ...
# 11           451
# 234          451
# 224          451
# 569          451
# 220          666
#
# [886 rows x 1 columns]

# %%
df2 = df1.loc[df1["user_id"] < 100]
df2
# Out:
# Empty DataFrame
# Columns: [user_id]
# Index: []

# %%
obsecure = df2.index.to_list()
obsecure

# %%
index_names = df[df["book_id"].isin(obsecure)].index
df = df.drop(index_names)
df

# %% [markdown]
# ## Split data
#
# Split data into 80% training and 20% testing

# %%
trainset, testset = train_test_split(df, test_size=0.2)

print("Training set size: ", trainset.shape)
print("Test set size: ", testset.shape)
# Out:
# Training set size:  (99872, 3)
# Test set size:  (24969, 3)

# %%
reader = Reader(line_format="user item rating", rating_scale=(1,5))
train_data = Dataset.load_from_df(trainset, reader)
test_data = Dataset.load_from_df(testset, reader)

# %%
test_data = test_data.build_full_trainset()
test_data = test_data.build_testset()

# %%
train_data = train_data.build_full_trainset()

# %% [markdown]
# ## Train Model
#
# Train a SVD model with 200 latent features

# %%
model = SVD(n_factors=100, n_epochs=30, reg_all=0.02, verbose=True)

# %%
model.fit(train_data)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29

# %% [markdown]
# ## Test Model

# %%
pred_test = model.test(test_data)
accuracy.rmse(pred_test)
# Out:
# RMSE: 0.6928
# 0.6928317750807189

# %%
df_predictions = pd.DataFrame(pred_test, columns=['uid', 'iid', 'rui', 'est', 'details'])
df_predictions['err'] = abs(df_predictions.est - df_predictions.rui)

df_predictions.head()
# Out:
#                                     uid  iid  rui       est  \
# 0  0c850f92-460b-4abc-b851-4bcd0ccbc94e  116  4.0  4.212945
# 1  0c850f92-460b-4abc-b851-4bcd0ccbc94e  421  2.0  3.097976
# 2  0c850f92-460b-4abc-b851-4bcd0ccbc94e    6  2.0  2.576427
# 3  0c850f92-460b-4abc-b851-4bcd0ccbc94e   60  5.0  3.388168
# 4  0c850f92-460b-4abc-b851-4bcd0ccbc94e  608  3.0  1.919026
#
#                      details       err
# 0  {'was_impossible': False}  0.212945
# 1  {'was_impossible': False}  1.097976
# 2  {'was_impossible': False}  0.576427
# 3  {'was_impossible': False}  1.611832
# 4  {'was_impossible': False}  1.080974

# %% [markdown]
# ## Find Best Prediction

# %%
best_predictions = df_predictions.sort_values(by='err')[:10]
best_predictions
# Out:
#                                         uid  iid  rui  est  \
# 16936  7bdb2ac3-5c7a-4ec6-a945-5ec837e06eda  343  1.0  1.0
# 16931  7bdb2ac3-5c7a-4ec6-a945-5ec837e06eda  926  1.0  1.0
# 6532   70decac3-bd50-47a4-8e45-33c10f5c6926  587  5.0  5.0
# 6537   70decac3-bd50-47a4-8e45-33c10f5c6926  254  5.0  5.0
# 6485   70decac3-bd50-47a4-8e45-33c10f5c6926  751  5.0  5.0
# 6487   70decac3-bd50-47a4-8e45-33c10f5c6926   64  5.0  5.0
# 22375  7a8b2147-a889-4c10-964a-19c23993f63a  271  5.0  5.0
# 18769  78f3a39c-08d2-4dce-ad38-0d47c8348a72  219  5.0  5.0
# 16898  7bdb2ac3-5c7a-4ec6-a945-5ec837e06eda  638  1.0  1.0
# 16900  7bdb2ac3-5c7a-4ec6-a945-5ec837e06eda  109  1.0  1.0
#
#                          details  err
# 16936  {'was_impossible': False}  0.0
# 16931  {'was_impossible': False}  0.0
# 6532   {'was_impossible': False}  0.0
# 6537   {'was_impossible': False}  0.0
# 6485   {'was_impossible': False}  0.0
# 6487   {'was_impossible': False}  0.0
# 22375  {'was_impossible': False}  0.0
# 18769  {'was_impossible': False}  0.0
# 16898  {'was_impossible': False}  0.0
# 16900  {'was_impossible': False}  0.0

# %% [markdown]
# ## Find Worst Prediction

# %%
worst_predictions = df_predictions.sort_values(by='err')[-10:]
worst_predictions
# Out:
#                                         uid  iid  rui       est  \
# 16884  7bdb2ac3-5c7a-4ec6-a945-5ec837e06eda  824  5.0  1.626474
# 13019  ddc3cbab-703b-4d49-b80b-89e3b884c802  627  1.0  4.416760
# 5722   85803de9-6591-4883-8f67-ad6dd5a405bc  335  1.0  4.490394
# 17685  593b3f3d-1983-4f20-b84e-6cc56117a4d5  593  1.0  4.653574
# 18822  fb41a9bc-3277-46c8-962a-e3ef58cdd421  179  1.0  4.747558
# 11762  f418f082-1417-4186-844e-517e64c4a66d  752  5.0  1.089636
# 16923  7bdb2ac3-5c7a-4ec6-a945-5ec837e06eda  220  5.0  1.064182
# 18010  4bad6b13-4387-4b44-9524-39d74b736a6b  754  1.0  4.937207
# 24097  d6494f6e-01b6-409e-a039-dc7b213300f8  783  1.0  4.956767
# 18050  4bad6b13-4387-4b44-9524-39d74b736a6b  277  1.0  5.000000
#
#                          details       err
# 16884  {'was_impossible': False}  3.373526
# 13019  {'was_impossible': False}  3.416760
# 5722   {'was_impossible': False}  3.490394
# 17685  {'was_impossible': False}  3.653574
# 18822  {'was_impossible': False}  3.747558
# 11762  {'was_impossible': False}  3.910364
# 16923  {'was_impossible': False}  3.935818
# 18010  {'was_impossible': False}  3.937207
# 24097  {'was_impossible': False}  3.956767
# 18050  {'was_impossible': False}  4.000000

# %% [markdown]
# ## Now fitting to full data (excluding books with < 100 ratings)

# %%
data = Dataset.load_from_df(df, reader)
data = data.build_full_trainset()

model.fit(data)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29

# %%
model.qi.shape
# Out:
# (886, 100)

# %%
pd.DataFrame(model.qi)
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.043023 -0.319651 -0.066558 -0.077602 -0.150253  0.297176 -0.125661
# 1   -0.214452 -0.101327  0.086615  0.048393 -0.054353  0.206596 -0.007356
# 2    0.225720 -0.167290  0.222587 -0.191411  0.314358  0.184888  0.353982
# 3    0.124207 -0.019404 -0.065053  0.078118 -0.147969  0.006256 -0.203950
# 4   -0.060680 -0.279450 -0.139020 -0.044696  0.081966  0.160476  0.039470
# ..        ...       ...       ...       ...       ...       ...       ...
# 881  0.168362  0.047393  0.205747  0.061471  0.003274 -0.104947  0.275797
# 882 -0.078118 -0.055733  0.177521  0.153407 -0.073289 -0.354206 -0.058046
# 883  0.137348  0.281783  0.245553 -0.009197  0.225086 -0.208190 -0.006119
# 884  0.080326 -0.145351  0.353249  0.004022  0.151557 -0.088666  0.051644
# 885  0.102102 -0.133235  0.083740 -0.071378 -0.236264 -0.058175 -0.025537
#
#            7         8         9   ...        90        91        92  \
# 0   -0.001561  0.289335  0.061583  ...  0.029865  0.072919 -0.043275
# 1    0.046981  0.159609 -0.095499  ...  0.276162  0.119729  0.019788
# 2    0.299889 -0.027567  0.025194  ...  0.212401 -0.037135  0.049537
# 3   -0.257661 -0.279606 -0.088558  ... -0.267170  0.266495 -0.116434
# 4   -0.079144  0.120323  0.240208  ...  0.162350 -0.094781 -0.142539
# ..        ...       ...       ...  ...       ...       ...       ...
# 881 -0.211896  0.062653 -0.039534  ...  0.258914  0.045883 -0.018999
# 882 -0.092125 -0.096062  0.049735  ... -0.143682  0.056484  0.060044
# 883 -0.038175  0.139033 -0.118896  ...  0.214449 -0.040270 -0.212041
# 884 -0.005518  0.213196 -0.276439  ... -0.090508  0.117698 -0.025483
# 885 -0.034854  0.070129  0.018395  ...  0.127362  0.193049 -0.215766
#
#            93        94        95        96        97        98        99
# 0    0.177479  0.191562 -0.208198  0.024303  0.459184 -0.068537  0.029893
# 1   -0.188448  0.072627  0.011838 -0.143431 -0.059901  0.109201 -0.108005
# 2   -0.044625  0.074143 -0.299344 -0.149682  0.046827  0.242303  0.112694
# 3    0.021859 -0.132600 -0.211786 -0.188322  0.407447 -0.023852  0.065913
# 4   -0.001717  0.187580 -0.155628 -0.253873  0.090758  0.097053 -0.016212
# ..        ...       ...       ...       ...       ...       ...       ...
# 881  0.173652  0.035382  0.120457  0.141245  0.047813 -0.033542 -0.094441
# 882  0.212731  0.187492  0.047430  0.360591  0.139575  0.030008 -0.231229
# 883  0.079835  0.049267  0.195690 -0.047314  0.146207  0.164586 -0.083914
# 884 -0.083395  0.053403  0.174225 -0.196947 -0.064747 -0.174062 -0.138868
# 885 -0.058866 -0.002375  0.424573 -0.042326 -0.059694 -0.052337  0.093232
#
# [886 rows x 100 columns]

# %% [markdown]
# # Dumping model to file

# %%
with gzip.open("svd_model. h5", "wb") as f:
    pickled = pickle.dumps(model)
    optimized_pickle = pickletools.optimize(pickled)
    f.write(optimized_pickle)
